# %% [markdown]
# <a href="https://colab.research.google.com/github/jespimentel/acidentes_piracicaba/blob/master/acidentes_piracicaba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Georreferenciamento e análise do banco de sentenças do TJSP
#
# ## Acidentes de trânsito em Piracicaba
#
# ### José Eduardo de Souza Pimentel (Jan/2026)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
# Importações necessárias

import os
import json
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from openai import OpenAI

# %%
# Configurações

MODELO = "gpt-5-mini" #"gpt-5-nano"
PATH_SENTENCAS = "/content/drive/MyDrive/Promotoria/Acidentes de trânsito"
MAX_INTERACOES = 10
CSV_SENTENCAS = '/content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas.csv'
CSV_SENTENCAS_ANALISADAS = '/content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas_analisadas.csv'
CSV_SENTENCAS_COM_ENDERECOS = '/content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas_com_enderecos.csv'
CSV_SENTENCAS_GEORREFERENCIADAS = '/content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas_georreferenciadas.csv'

# Limites geográficos (cantos do retângulo)
PONTO_1 = (-22.59505, -47.87594)
PONTO_2 = (-22.86262, -47.41858)

# %%
# Parametrização da requisição ao TJSP

PARAMS_TJSP = params = {
    "conversationId": "",
    "dadosConsulta.pesquisaLivre": "",
    "tipoNumero": "UNIFICADO",
    "numeroDigitoAnoUnificado": "",
    "foroNumeroUnificado": "",
    "dadosConsulta.nuProcesso": "",
    "dadosConsulta.nuProcessoAntigo": "",
    "classeTreeSelection.values": "",
    "classeTreeSelection.text": "",
    "assuntoTreeSelection.values": "3632",
    "assuntoTreeSelection.text": "",
    "agenteSelectedEntitiesList": "",
    "contadoragente": "0",
    "contadorMaioragente": "0",
    "cdAgente": "",
    "nmAgente": "",
    "dadosConsulta.dtInicio": "",
    "dadosConsulta.dtFim": "",
    "varasTreeSelection.values": "451-10,451-8,451-7101,451-7084,451-7094,451-7095,451-9,451-5623",
    "varasTreeSelection.text": "8 Registros selecionados",
    "dadosConsulta.ordenacao": "DESC"
}

# %% [markdown]
# # Download das sentenças

# %%
# Cria uma sessão persistente
session = requests.Session()

# 1a requisição para obter os cookies
response = session.get("https://esaj.tjsp.jus.br/cjpg/pesquisar.do", params=PARAMS_TJSP)

if response.status_code == 200:
    for i in range(1, MAX_INTERACOES + 1):
        pagina = str(i)
        url_pagina = f"https://esaj.tjsp.jus.br/cjpg/trocarDePagina.do?pagina={pagina}&conversationId="

        # Usa a mesma sessão para fazer a requisição
        response = session.get(url_pagina)

        if response.status_code == 200:
            # Salva o conteúdo da página
            with open(f"{PATH_SENTENCAS}/pagina_{pagina}.html", "wb") as file:
                file.write(response.content)
            print(f"Página {pagina} salva com sucesso.")
        else:
            print(f"Erro ao acessar a página {pagina}: {response.status_code}")

        # Intervalo entre requisições
        time.sleep(1)
else:
    print("Erro ao acessar a página inicial.")
# Out:
# Página 1 salva com sucesso.
# Página 2 salva com sucesso.
# Página 3 salva com sucesso.
# Página 4 salva com sucesso.
# Página 5 salva com sucesso.
# Página 6 salva com sucesso.
# Página 7 salva com sucesso.
# Página 8 salva com sucesso.
# Página 9 salva com sucesso.
# Página 10 salva com sucesso.

# %% [markdown]
# # Criação do dataframe

# %%
def extrair_informacoes_html(html_path):
    processos = []
    with open(html_path, "r", encoding="utf-8") as file:
        soup = BeautifulSoup(file, "html.parser")
        textos = soup.find_all(class_="fundocinza1")
        for texto in textos:
            processo = {}
            # Número do Processo
            processo['numero_do_processo'] = texto.find('span', class_='fonteNegrito').text.strip()

            # Classe, Assunto, Magistrado, Comarca, Foro, Vara, Data de Disponibilização
            for row in texto.find_all('tr', class_='fonte'):
                if row.find('strong'):
                    key = row.find('strong').text.strip().replace(':', '').lower().replace(' ', '_')
                    value = row.find('strong').next_sibling.strip()
                    processo[key] = value

            # Sentença
            sentenca_divs = texto.find_all('div', align='justify')
            sentenca = ''
            for div in sentenca_divs:
                span = div.find('span')
                if span:
                    sentenca += span.text.strip() + '\n'
            processo['sentenca'] = sentenca.strip()

            processos.append(processo)

        return processos

# %%
data = []

for filename in os.listdir(PATH_SENTENCAS):
    if filename.endswith(".html"):
        filepath = os.path.join(PATH_SENTENCAS, filename)
        data += (extrair_informacoes_html(filepath))

# Cria o DataFrame
df = pd.DataFrame(data)
df.head(5)
# Out:
#           numero_do_processo                               classe  \
# 0  1500571-62.2024.8.26.0451                   Inquérito Policial
# 1  1502202-19.2023.8.26.0599    Ação Penal - Procedimento Sumário
# 2  1502522-67.2019.8.26.0451  Ação Penal - Procedimento Ordinário
# 3  1501240-52.2023.8.26.0451  Ação Penal - Procedimento Ordinário
# 4  0013813-80.2015.8.26.0451  Ação Penal - Procedimento Ordinário
#
#               assunto                             magistrado     comarca  \
# 0  Crimes de Trânsito        Ana Claudia Madeira de Oliveira  Piracicaba
# 1  Crimes de Trânsito  Flavia de Cassia Gonzales de Oliveira  Piracicaba
# 2  Crimes de Trânsito                                    NaN  Piracicaba
# 3  Crimes de Trânsito        Ana Claudia Madeira de Oliveira  Piracicaba
# 4  Crimes de Trânsito                                    NaN  Piracicaba
#
#                  foro              vara data_de_disponibilização  \
# 0  Foro de Piracicaba  1ª Vara Criminal               05/11/2025
# 1  Foro de Piracicaba  2ª Vara Criminal               04/11/2025
# 2  Foro de Piracicaba  4ª Vara Criminal               31/10/2025
# 3  Foro de Piracicaba  1ª Vara Criminal               31/10/2025
# 4  Foro de Piracicaba  2ª Vara Criminal               30/10/2025
#
#                                             sentenca
# 0  SENTENÇA\n\nProcesso nº:\t1500571-62.2024.8.26...
# 1
# 2
# 3  SENTENÇA\n\nProcesso Digital nº:\t1501240-52.2...
# 4

# %%
# Cria o dataframe com sentenças não vazias e salva em CSV
df_1 = df[(df['sentenca']!='')]
df_1 = df_1.drop_duplicates(subset=['numero_do_processo'], keep='last') # Despreza os processos repetidos
df_1.reset_index(drop=True, inplace=True)
df_1.to_csv(CSV_SENTENCAS, index=False, encoding='utf-8-sig')  # utf-8-sig para compatibilidade com Excel
print(f"Arquivo CSV salvo em: {CSV_SENTENCAS}")
# Out:
# Arquivo CSV salvo em: /content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas.csv

# %% [markdown]
# # Consulta à API OpenAI para análise das sentenças

# %%
# Análisar com a LLM

SYSTEM_MSG = (
    "Você é assessor jurídico especializado em direito penal. "
    "Responda exclusivamente em JSON válido, sem comentários, com as chaves: "
    "'data_fato', 'endereco_fato', 'conduta_culposa'."
)

USER_TEMPLATE = (
    "Analise o texto a seguir e devolva um objeto JSON contendo as chaves já indicadas."
    "Para a chave 'data_fato' responda apenas com a data do fato (ex.: 24/03/2025)"
    "ou escreva 'Não se aplica'."
    "Para a chave 'endereco_fato' responda com o endereço principal do fato "
    "(ex.: rua Alvorada, 123, bairro Jardim Brasília, Piracicaba/SP)."
    "ou escreva 'Não se aplica'."
    "Para a chave 'conduta_culposa', resuma em até 100 palavras o porquê de ter havido o acidente, com "
    "enfase na conduta culposa. "
    "ou escreva 'Não se aplica'."
    "RESTRIÇÕES: para todos os casos, não mencione nomes. Use as iniciais dos envolvidos, "
    "caso precise referenciá-los.\n\n"
    "TEXTO FORNECIDO PARA ANÁLISE:\n\n{texto_fornecido}"
)

client = OpenAI(api_key=OPENAI_API_KEY)

def analisar_sentenca(texto_fornecido: str) -> dict:
    resposta_api = None

    try:
        response = client.chat.completions.create(
            model=MODELO,
            response_format={"type": "json_object"},
            messages=[
                {"role": "system", "content": SYSTEM_MSG},
                {"role": "user", "content": USER_TEMPLATE.format(texto_fornecido=texto_fornecido)}
            ]
        )

        if (
            response
            and response.choices
            and response.choices[0].message
            and response.choices[0].message.content
        ):
            resposta_api = response.choices[0].message.content.strip()
        else:
            resposta_api = "Erro: Resposta da API em formato inesperado."
            print(f"Resposta inesperada da API: {response}")

    except Exception as e:
        resposta_api = f"Erro ao processar com OpenAI: {e}"

    return resposta_api

# %%
import json
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

# 1. Definimos a função de processamento individual
def processar_linha(row):
    n_processo = row['numero_do_processo']
    print(f"Analisando o processo {n_processo}...")

    # Chamada da sua função original da API
    resposta_texto = analisar_sentenca(row['sentenca'])

    try:
        analise = json.loads(resposta_texto)
    except Exception as e:
        print(f"Erro ao converter JSON no processo {n_processo}: {e}")
        print("Resposta bruta da API:", resposta_texto)
        analise = {
            "data_fato": "Não se aplica",
            "endereco_fato": "Não se aplica",
            "conduta_culposa": "Não se aplica",
        }

    return (n_processo, analise)

# 2. Execução Paralela
# max_workers define quantas requisições ocorrem simultaneamente
MAX_REQUISICOES_SIMULTANEAS = 10

with ThreadPoolExecutor(max_workers=MAX_REQUISICOES_SIMULTANEAS) as executor:
    # Mapeia a função para cada linha do DataFrame
    # list() força a execução de todos os processos
    lista_de_respostas = list(executor.map(processar_linha, [row for _, row in df_1.iterrows()]))

# Resultado: lista_de_respostas conterá as tuplas (n_processo, analise)
# Out:
# Analisando o processo 1502313-93.2022.8.26.0451...
# Analisando o processo 0009883-88.2014.8.26.0451...
# Analisando o processo 1502947-89.2022.8.26.0451...
# Analisando o processo 1502796-60.2021.8.26.0451...
# Analisando o processo 0014888-04.2008.8.26.0451...
# Analisando o processo 1500571-62.2024.8.26.0451...
# Analisando o processo 1501240-52.2023.8.26.0451...
# Analisando o processo 0002547-33.2014.8.26.0451...
# Analisando o processo 1544390-88.2020.8.26.0451...
# Analisando o processo 1512031-80.2023.8.26.0451...
# Analisando o processo 0033917-98.2012.8.26.0451...
# Analisando o processo 1510468-51.2023.8.26.0451...
# Analisando o processo 1502522-67.2019.8.26.0451...
# Analisando o processo 1501608-32.2021.8.26.0451...
# Analisando o processo 1502827-51.2019.8.26.0451...
# Analisando o processo 1500311-26.2024.8.26.0599...
# Analisando o processo 0002976-63.2015.8.26.0451...
# Analisando o processo 0008586-12.2015.8.26.0451...
# Analisando o processo 1515776-44.2018.8.26.0451...
# Analisando o processo 1532574-12.2020.8.26.0451...
# Analisando o processo 1547052-54.2022.8.26.0451...
# Analisando o processo 1507378-98.2024.8.26.0451...
# Analisando o processo 1509412-80.2023.8.26.0451...
# Analisando o processo 0003976-93.2018.8.26.0451...
# Analisando o processo 0007376-18.2018.8.26.0451...
# Analisando o processo 1501593-36.2023.8.26.0599...
# Analisando o processo 1507105-22.2024.8.26.0451...
# Analisando o processo 1500841-23.2023.8.26.0451...
# Analisando o processo 1502466-58.2024.8.26.0451...
# Analisando o processo 0008770-07.2011.8.26.0451...
# Analisando o processo 1542610-45.2022.8.26.0451...
# Analisando o processo 1501434-98.2020.8.26.0599...
# Analisando o processo 0070380-54.2003.8.26.0451...
# Analisando o processo 0008450-83.2013.8.26.0451...
# Analisando o processo 1504673-30.2024.8.26.0451...
# Analisando o processo 1503284-15.2021.8.26.0451...
# Analisando o processo 1501728-87.2019.8.26.0599...
# Analisando o processo 1500310-80.2020.8.26.0599...
# Analisando o processo 1502345-98.2022.8.26.0451...
# Analisando o processo 0002960-12.2015.8.26.0451...
# Analisando o processo 1502086-35.2024.8.26.0451...
# Analisando o processo 1512013-59.2023.8.26.0451...
# Analisando o processo 1509069-26.2019.8.26.0451...
# Analisando o processo 0005901-37.2012.8.26.0451...
# Analisando o processo 1501753-88.2021.8.26.0451...
# Analisando o processo 0014292-49.2010.8.26.0451...
# Analisando o processo 1500476-37.2021.8.26.0451...
# Analisando o processo 1545490-78.2020.8.26.0451...
# Analisando o processo 1543447-71.2020.8.26.0451...
# Analisando o processo 0001287-18.2014.8.26.0451...
# Analisando o processo 1501789-33.2021.8.26.0451...
# Analisando o processo 1509511-89.2019.8.26.0451...
# Analisando o processo 1501622-16.2021.8.26.0451...
# Analisando o processo 1500904-31.2019.8.26.0599...
# Analisando o processo 1519313-48.2018.8.26.0451...
# Analisando o processo 1509742-82.2020.8.26.0451...
# Analisando o processo 3011538-78.2013.8.26.0451...
# Analisando o processo 0014299-94.2017.8.26.0451...
# Analisando o processo 1503644-18.2019.8.26.0451...
# Analisando o processo 0005222-61.2017.8.26.0451...
# Analisando o processo 0014725-14.2014.8.26.0451...
# Analisando o processo 0007185-75.2015.8.26.0451...
# Analisando o processo 0014861-74.2015.8.26.0451...
# Analisando o processo 0003527-14.2013.8.26.0451...
# Analisando o processo 0007080-64.2016.8.26.0451...
# Analisando o processo 1502849-12.2019.8.26.0451...
# Analisando o processo 1501965-53.2021.8.26.0599...
# Analisando o processo 0005723-49.2016.8.26.0451...
# Analisando o processo 1542438-74.2020.8.26.0451...
# Analisando o processo 0003317-45.2022.8.26.0451...
# Analisando o processo 1501187-76.2020.8.26.0451...
# Analisando o processo 1512235-66.2019.8.26.0451...
# Analisando o processo 0005188-52.2018.8.26.0451...
# Analisando o processo 0000679-22.2018.8.26.0599...
# Analisando o processo 1501833-64.2019.8.26.0599...
# Analisando o processo 1524669-53.2020.8.26.0451...
# Analisando o processo 3001171-92.2013.8.26.0451...
# Analisando o processo 0006806-42.2012.8.26.0451...
# Analisando o processo 0016577-39.2015.8.26.0451...
# Analisando o processo 0002197-45.2014.8.26.0451...
# Analisando o processo 1540869-09.2018.8.26.0451...
# Analisando o processo 0024302-21.2011.8.26.0451...
# Analisando o processo 1503786-51.2021.8.26.0451...
# Analisando o processo 1502688-31.2021.8.26.0451...
# Analisando o processo 0005024-63.2013.8.26.0451...
# Analisando o processo 1502908-29.2021.8.26.0451...
# Analisando o processo 3004871-76.2013.8.26.0451...
# Analisando o processo 0015430-41.2016.8.26.0451...
# Analisando o processo 1501779-98.2019.8.26.0599...
# Analisando o processo 1510446-32.2019.8.26.0451...
# Analisando o processo 0029594-50.2012.8.26.0451...
# Analisando o processo 1500806-34.2021.8.26.0451...
# Analisando o processo 1534224-65.2018.8.26.0451...
# Analisando o processo 0002052-18.2016.8.26.0451...
# Analisando o processo 1501639-64.2019.8.26.0599...
# Analisando o processo 1501594-60.2019.8.26.0599...
# Analisando o processo 1500867-26.2020.8.26.0451...
# Analisando o processo 0004237-29.2016.8.26.0451...
# Analisando o processo 0013760-02.2015.8.26.0451...
# Analisando o processo 1500287-71.2019.8.26.0599...
# Analisando o processo 1528138-78.2018.8.26.0451...
# Analisando o processo 0010162-06.2016.8.26.0451...
# Analisando o processo 1501595-45.2019.8.26.0599...
# Analisando o processo 0014601-60.2016.8.26.0451...
# Analisando o processo 0013676-98.2015.8.26.0451...
# Analisando o processo 1504518-03.2019.8.26.0451...
# Analisando o processo 0021150-57.2014.8.26.0451...
# Analisando o processo 0005731-26.2016.8.26.0451...
# Analisando o processo 0015638-25.2016.8.26.0451...
# Analisando o processo 1500573-49.2019.8.26.0599...
# Analisando o processo 0035754-28.2011.8.26.0451...
# Analisando o processo 0007857-15.2017.8.26.0451...
# Analisando o processo 0015362-91.2016.8.26.0451...
# Analisando o processo 0004371-27.2014.8.26.0451...
# Analisando o processo 1501478-83.2021.8.26.0599...
# Analisando o processo 1500149-63.2019.8.26.0451...
# Analisando o processo 1501055-94.2019.8.26.0599...
# Analisando o processo 1544365-75.2020.8.26.0451...
# Analisando o processo 1502483-07.2018.8.26.0451...
# Analisando o processo 0009939-87.2015.8.26.0451...
# Analisando o processo 0019469-57.2011.8.26.0451...
# Analisando o processo 0002794-72.2018.8.26.0451...
# Analisando o processo 0014287-80.2017.8.26.0451...
# Analisando o processo 0000368-31.2018.8.26.0599...
# Analisando o processo 0004680-14.2015.8.26.0451...
# Analisando o processo 0036372-36.2012.8.26.0451...
# Analisando o processo 0014902-07.2016.8.26.0451...
# Analisando o processo 0013791-85.2016.8.26.0451...
# Analisando o processo 1540078-40.2018.8.26.0451...
# Analisando o processo 1542264-36.2018.8.26.0451...
# Analisando o processo 0013000-19.2016.8.26.0451...
# Analisando o processo 0000267-91.2018.8.26.0599...
# Analisando o processo 0009529-53.2020.8.26.0451...
# Analisando o processo 0001679-79.2019.8.26.0451...
# Analisando o processo 0017885-42.2017.8.26.0451...
# Analisando o processo 0006392-34.2018.8.26.0451...
# Analisando o processo 1500289-75.2018.8.26.0599...
# Analisando o processo 0002553-98.2018.8.26.0451...
# Analisando o processo 1500701-69.2019.8.26.0599...
# Analisando o processo 0001815-13.2018.8.26.0451...
# Analisando o processo 1506466-77.2019.8.26.0451...
# Analisando o processo 0031967-54.2012.8.26.0451...
# Analisando o processo 1500333-60.2019.8.26.0599...
# Analisando o processo 0009511-37.2017.8.26.0451...
# Analisando o processo 0009432-24.2018.8.26.0451...
# Analisando o processo 0000720-23.2017.8.26.0599...
# Analisando o processo 0000680-12.2015.8.26.0599...
# Analisando o processo 3007964-47.2013.8.26.0451...
# Analisando o processo 1501071-14.2020.8.26.0599...
# Analisando o processo 1534222-95.2018.8.26.0451...
# Analisando o processo 1500379-49.2019.8.26.0599...
# Analisando o processo 1545900-39.2020.8.26.0451...
# Analisando o processo 3011550-92.2013.8.26.0451...
# Analisando o processo 0002274-25.2012.8.26.0451...
# Analisando o processo 0005279-45.2018.8.26.0451...
# Analisando o processo 1500625-79.2018.8.26.0599...
# Analisando o processo 0008373-11.2012.8.26.0451...
# Analisando o processo 0011841-07.2017.8.26.0451...
# Analisando o processo 1500667-31.2018.8.26.0599...
# Analisando o processo 0011822-98.2017.8.26.0451...
# Analisando o processo 1500642-18.2018.8.26.0599...
# Analisando o processo 0001275-33.2016.8.26.0451...
# Analisando o processo 0011425-39.2017.8.26.0451...
# Analisando o processo 0073291-39.2003.8.26.0451...
# Analisando o processo 0000252-81.2018.8.26.0451...
# Analisando o processo 0007593-95.2017.8.26.0451...
# Analisando o processo 1500203-07.2018.8.26.0599...
# Analisando o processo 0000169-09.2018.8.26.0599...
# Analisando o processo 0011095-42.2017.8.26.0451...
# Analisando o processo 0005625-30.2017.8.26.0451...
# Analisando o processo 0003903-24.2018.8.26.0451...
# Analisando o processo 0015256-66.2015.8.26.0451...
# Analisando o processo 0003304-56.2016.8.26.0451...
# Analisando o processo 0025936-18.2012.8.26.0451...
# Analisando o processo 0019185-49.2011.8.26.0451...
# Analisando o processo 0000920-62.2012.8.26.0451...
# Analisando o processo 0007312-76.2016.8.26.0451...
# Analisando o processo 0002074-42.2017.8.26.0451...
# Analisando o processo 0000995-69.2017.8.26.0599...
# Analisando o processo 0000524-19.2018.8.26.0599...
# Analisando o processo 0009852-97.2016.8.26.0451...
# Analisando o processo 1509013-90.2019.8.26.0451...
# Analisando o processo 0011656-03.2016.8.26.0451...
# Analisando o processo 1500064-55.2018.8.26.0599...
# Analisando o processo 0013696-55.2016.8.26.0451...
# Analisando o processo 0012238-66.2017.8.26.0451...
# Analisando o processo 0000944-17.2017.8.26.0451...
# Analisando o processo 0006481-28.2016.8.26.0451...
# Analisando o processo 0014627-24.2017.8.26.0451...
# Analisando o processo 0011861-95.2017.8.26.0451...
# Analisando o processo 0014900-37.2016.8.26.0451...
# Analisando o processo 1501265-48.2019.8.26.0599...
# Analisando o processo 0013582-19.2016.8.26.0451...
# Analisando o processo 0011935-86.2016.8.26.0451...
# Analisando o processo 0016760-73.2016.8.26.0451...
# Analisando o processo 0000237-56.2018.8.26.0599...
# Analisando o processo 0000710-76.2017.8.26.0599...
# Analisando o processo 0033480-28.2010.8.26.0451...
# Analisando o processo 0014626-39.2017.8.26.0451...
# Analisando o processo 0000208-33.2016.8.26.0451...
# Analisando o processo 0011929-79.2016.8.26.0451...
# Analisando o processo 0005384-61.2014.8.26.0451...
# Analisando o processo 0000131-31.2017.8.26.0599...
# Analisando o processo 0002419-18.2011.8.26.0451...
# Analisando o processo 0002487-26.2015.8.26.0451...
# Analisando o processo 0000262-06.2017.8.26.0599...
# Analisando o processo 0008524-35.2016.8.26.0451...
# Analisando o processo 0000941-04.2013.8.26.0451...
# Analisando o processo 0036374-06.2012.8.26.0451...
# Analisando o processo 0000421-05.2017.8.26.0451...
# Analisando o processo 0013046-71.2017.8.26.0451...
# Analisando o processo 0021564-55.2014.8.26.0451...
# Analisando o processo 0012631-25.2016.8.26.0451...
# Analisando o processo 0000446-93.2016.8.26.0599...
# Analisando o processo 0009783-65.2016.8.26.0451...
# Analisando o processo 0008272-61.2018.8.26.0451...
# Analisando o processo 0014342-36.2014.8.26.0451...
# Analisando o processo 0001026-89.2017.8.26.0599...
# Analisando o processo 0008559-58.2017.8.26.0451...
# Analisando o processo 0000856-13.2016.8.26.0451...
# Analisando o processo 0018547-11.2014.8.26.0451...
# Analisando o processo 0020812-88.2011.8.26.0451...
# Analisando o processo 0014986-08.2016.8.26.0451...
# Analisando o processo 0008010-82.2016.8.26.0451...
# Analisando o processo 0014290-69.2016.8.26.0451...
# Analisando o processo 0015359-39.2016.8.26.0451...
# Analisando o processo 0001711-26.2015.8.26.0451...
# Analisando o processo 0000209-52.2015.8.26.0451...
# Analisando o processo 0000241-64.2016.8.26.0599...
# Analisando o processo 0000668-90.2018.8.26.0599...
# Analisando o processo 0019971-59.2012.8.26.0451...
# Analisando o processo 0007079-79.2016.8.26.0451...
# Analisando o processo 0005347-97.2015.8.26.0451...
# Analisando o processo 0001733-16.2017.8.26.0451...
# Analisando o processo 0018642-12.2012.8.26.0451...
# Analisando o processo 0014888-57.2015.8.26.0451...
# Analisando o processo 0013838-30.2014.8.26.0451...
# Analisando o processo 0001139-80.2009.8.26.0451...
# Analisando o processo 0007056-46.2010.8.26.0451...
# Analisando o processo 0000454-70.2016.8.26.0599...
# Analisando o processo 0014996-23.2014.8.26.0451...
# Analisando o processo 0013932-75.2014.8.26.0451...
# Analisando o processo 0011359-93.2016.8.26.0451...
# Analisando o processo 0000393-37.2017.8.26.0451...
# Analisando o processo 0012655-87.2015.8.26.0451...
# Analisando o processo 0009303-58.2014.8.26.0451...
# Analisando o processo 0003432-13.2015.8.26.0451...
# Analisando o processo 0004373-26.2016.8.26.0451...
# Analisando o processo 0016983-94.2014.8.26.0451...
# Analisando o processo 0017132-22.2016.8.26.0451...
# Analisando o processo 0011482-28.2015.8.26.0451...
# Analisando o processo 0026335-52.2009.8.26.0451...
# Analisando o processo 0014631-95.2016.8.26.0451...
# Analisando o processo 0001619-14.2016.8.26.0451...
# Analisando o processo 0000260-70.2016.8.26.0599...
# Analisando o processo 0049576-70.2000.8.26.0451...
# Analisando o processo 0010514-95.2015.8.26.0451...
# Analisando o processo 0001660-78.2016.8.26.0451...
# Analisando o processo 0006474-36.2016.8.26.0451...
# Analisando o processo 0011416-48.2015.8.26.0451...
# Analisando o processo 0005804-32.2015.8.26.0451...
# Analisando o processo 0006055-16.2016.8.26.0451...
# Analisando o processo 0018840-93.2005.8.26.0451...
# Analisando o processo 0011815-82.2012.8.26.0451...
# Analisando o processo 0013919-08.2016.8.26.0451...
# Analisando o processo 0007184-90.2015.8.26.0451...
# Analisando o processo 0019815-76.2009.8.26.0451...
# Analisando o processo 0032586-33.2002.8.26.0451...
# Analisando o processo 0015064-02.2016.8.26.0451...
# Analisando o processo 0012556-54.2014.8.26.0451...
# Analisando o processo 0027565-27.2012.8.26.0451...
# Analisando o processo 0016968-91.2015.8.26.0451...
# Analisando o processo 0000225-13.2016.8.26.0599...
# Analisando o processo 0021065-71.2014.8.26.0451...
# Analisando o processo 0007181-38.2015.8.26.0451...
# Analisando o processo 0021500-21.2009.8.26.0451...
# Analisando o processo 0014898-67.2016.8.26.0451...
# Analisando o processo 0007070-20.2016.8.26.0451...
# Analisando o processo 0012724-85.2016.8.26.0451...
# Analisando o processo 1500148-56.2018.8.26.0599...
# Analisando o processo 0034605-60.2012.8.26.0451...
# Analisando o processo 0007783-92.2016.8.26.0451...
# Analisando o processo 0001209-53.2016.8.26.0451...
# Analisando o processo 0010325-83.2016.8.26.0451...
# Analisando o processo 0006045-69.2016.8.26.0451...
# Analisando o processo 0005797-74.2014.8.26.0451...
# Analisando o processo 3015973-95.2013.8.26.0451...
# Analisando o processo 0000426-05.2016.8.26.0599...
# Analisando o processo 0007828-96.2016.8.26.0451...
# Analisando o processo 0006916-02.2016.8.26.0451...
# Analisando o processo 0017682-51.2015.8.26.0451...
# Analisando o processo 0005971-49.2015.8.26.0451...
# Analisando o processo 0018200-41.2015.8.26.0451...
# Analisando o processo 0008805-64.2011.8.26.0451...
# Analisando o processo 0000132-50.2016.8.26.0599...
# Analisando o processo 0011987-48.2017.8.26.0451...
# Analisando o processo 0002462-76.2016.8.26.0451...
# Analisando o processo 3013647-65.2013.8.26.0451...
# Analisando o processo 0019439-22.2011.8.26.0451...
# Analisando o processo 0002028-92.2013.8.26.0451...
# Analisando o processo 0021427-73.2014.8.26.0451...
# Analisando o processo 0011543-20.2014.8.26.0451...
# Analisando o processo 0012138-82.2015.8.26.0451...
# Analisando o processo 0007315-65.2015.8.26.0451...
# Analisando o processo 0012927-81.2015.8.26.0451...
# Analisando o processo 0003134-89.2013.8.26.0451...
# Analisando o processo 0003351-30.2016.8.26.0451...
# Analisando o processo 0017644-39.2015.8.26.0451...
# Analisando o processo 0000507-78.2014.8.26.0451...
# Analisando o processo 0031968-39.2012.8.26.0451...
# Analisando o processo 3010620-74.2013.8.26.0451...
# Analisando o processo 0007462-57.2016.8.26.0451...
# Analisando o processo 0007978-14.2015.8.26.0451...
# Analisando o processo 0005671-53.2016.8.26.0451...
# Analisando o processo 0000562-58.2016.8.26.0451...
# Analisando o processo 0000683-64.2015.8.26.0599...
# Analisando o processo 0005652-13.2017.8.26.0451...
# Analisando o processo 0009235-74.2015.8.26.0451...
# Analisando o processo 0018083-84.2014.8.26.0451...
# Analisando o processo 0009170-45.2016.8.26.0451...
# Analisando o processo 0003903-63.2014.8.26.0451...
# Analisando o processo 0000019-96.2016.8.26.0599...
# Analisando o processo 0008892-44.2016.8.26.0451...
# Analisando o processo 0009202-21.2014.8.26.0451...
# Analisando o processo 0009211-46.2015.8.26.0451...
# Analisando o processo 0005195-15.2016.8.26.0451...
# Analisando o processo 0000965-61.2015.8.26.0451...
# Analisando o processo 0011921-73.2014.8.26.0451...
# Analisando o processo 0000865-09.2015.8.26.0451...
# Analisando o processo 0000515-62.2015.8.26.0599...
# Analisando o processo 0011483-47.2014.8.26.0451...
# Analisando o processo 0013867-80.2014.8.26.0451...
# Analisando o processo 0000166-25.2016.8.26.0599...
# Analisando o processo 0032811-04.2012.8.26.0451...
# Analisando o processo 0018955-02.2014.8.26.0451...
# Analisando o processo 3010610-30.2013.8.26.0451...
# Analisando o processo 0013675-50.2014.8.26.0451...
# Analisando o processo 0000252-93.2016.8.26.0599...
# Analisando o processo 0002122-35.2016.8.26.0451...
# Analisando o processo 0003868-69.2015.8.26.0451...
# Analisando o processo 0011910-44.2014.8.26.0451...
# Analisando o processo 0004973-86.2012.8.26.0451...
# Analisando o processo 0002119-46.2017.8.26.0451...
# Analisando o processo 0000015-86.2014.8.26.0451...
# Analisando o processo 0017783-88.2015.8.26.0451...
# Analisando o processo 0008665-88.2015.8.26.0451...
# Analisando o processo 0004463-34.2016.8.26.0451...
# Analisando o processo 0007186-60.2015.8.26.0451...
# Analisando o processo 0009281-97.2014.8.26.0451...
# Analisando o processo 0013542-71.2015.8.26.0451...
# Analisando o processo 0018230-76.2015.8.26.0451...
# Analisando o processo 0007313-66.2013.8.26.0451...
# Analisando o processo 0000121-55.2015.8.26.0599...
# Analisando o processo 3007969-69.2013.8.26.0451...
# Analisando o processo 0004372-41.2016.8.26.0451...
# Analisando o processo 0011581-13.2006.8.26.0451...
# Analisando o processo 0009695-32.2013.8.26.0451...
# Analisando o processo 0016100-50.2014.8.26.0451...
# Analisando o processo 0000418-55.2014.8.26.0451...
# Analisando o processo 0001559-46.2013.8.26.0451...
# Analisando o processo 0000479-20.2015.8.26.0599...
# Analisando o processo 0000678-42.2015.8.26.0599...
# Analisando o processo 0018446-71.2014.8.26.0451...
# Analisando o processo 0004414-27.2015.8.26.0451...
# Analisando o processo 0007128-91.2014.8.26.0451...
# Analisando o processo 0006130-89.2015.8.26.0451...
# Analisando o processo 0005505-55.2015.8.26.0451...
# Analisando o processo 0007980-81.2015.8.26.0451...
# Analisando o processo 0019996-04.2014.8.26.0451...
# Analisando o processo 0000072-14.2015.8.26.0599...
# Analisando o processo 0015073-95.2015.8.26.0451...
# Analisando o processo 0007814-83.2014.8.26.0451...
# Analisando o processo 0008122-27.2011.8.26.0451...
# Analisando o processo 0015293-30.2014.8.26.0451...
# Analisando o processo 0002486-41.2015.8.26.0451...
# Analisando o processo 0010062-56.2013.8.26.0451...
# Analisando o processo 0000158-48.2016.8.26.0599...
# Analisando o processo 0021232-59.2012.8.26.0451...
# Analisando o processo 0000449-82.2015.8.26.0599...
# Analisando o processo 0014067-53.2015.8.26.0451...
# Analisando o processo 0019813-33.2014.8.26.0451...
# Analisando o processo 0020730-52.2014.8.26.0451...
# Analisando o processo 0020023-84.2014.8.26.0451...
# Analisando o processo 0013340-31.2014.8.26.0451...
# Analisando o processo 0029885-21.2010.8.26.0451...
# Analisando o processo 0032249-73.2004.8.26.0451...
# Analisando o processo 0020123-39.2014.8.26.0451...
# Analisando o processo 0000073-62.2016.8.26.0599...
# Analisando o processo 0000457-59.2015.8.26.0599...
# Analisando o processo 0025894-13.2005.8.26.0451...
# Analisando o processo 0003082-59.2014.8.26.0451...
# Analisando o processo 0019392-43.2014.8.26.0451...
# Analisando o processo 0000445-45.2015.8.26.0599...
# Analisando o processo 0001057-12.2017.8.26.0599...
# Analisando o processo 0033922-23.2012.8.26.0451...
# Analisando o processo 0000945-02.2017.8.26.0451...
# Analisando o processo 0005830-40.2009.8.26.0451...
# Analisando o processo 0024522-82.2012.8.26.0451...
# Analisando o processo 0010526-12.2015.8.26.0451...
# Analisando o processo 3010621-59.2013.8.26.0451...
# Analisando o processo 0006939-16.2014.8.26.0451...
# Analisando o processo 0005642-37.2015.8.26.0451...
# Analisando o processo 0028449-37.2004.8.26.0451...
# Analisando o processo 3010954-11.2013.8.26.0451...
# Analisando o processo 0023444-24.2010.8.26.0451...
# Analisando o processo 0003604-18.2016.8.26.0451...
# Analisando o processo 0004758-71.2016.8.26.0451...
# Analisando o processo 3014238-27.2013.8.26.0451...
# Analisando o processo 0015159-66.2015.8.26.0451...
# Analisando o processo 0031290-24.2012.8.26.0451...
# Analisando o processo 3006025-32.2013.8.26.0451...
# Analisando o processo 0000476-65.2015.8.26.0599...
# Analisando o processo 0026151-62.2010.8.26.0451...
# Analisando o processo 0004281-82.2015.8.26.0451...
# Analisando o processo 0000488-79.2015.8.26.0599...
# Analisando o processo 0009697-02.2013.8.26.0451...
# Analisando o processo 0012839-77.2014.8.26.0451...
# Analisando o processo 0000011-90.2014.8.26.0599...
# Analisando o processo 0003056-61.2014.8.26.0451...
# Analisando o processo 3012253-23.2013.8.26.0451...
# Analisando o processo 0004932-17.2015.8.26.0451...
# Analisando o processo 0008414-41.2013.8.26.0451...
# Analisando o processo 3004900-29.2013.8.26.0451...
# Analisando o processo 0008633-20.2014.8.26.0451...
# Analisando o processo 0017411-76.2014.8.26.0451...
# Analisando o processo 0000222-92.2015.8.26.0599...
# Analisando o processo 0012627-56.2014.8.26.0451...
# Analisando o processo 0023111-09.2009.8.26.0451...
# Analisando o processo 0011180-96.2015.8.26.0451...
# Analisando o processo 0012861-38.2014.8.26.0451...
# Analisando o processo 0013823-61.2014.8.26.0451...
# Analisando o processo 0007034-46.2014.8.26.0451...
# Analisando o processo 0025316-40.2011.8.26.0451...
# Analisando o processo 0011548-08.2015.8.26.0451...
# Analisando o processo 0000880-75.2015.8.26.0451...
# Analisando o processo 0052233-48.2001.8.26.0451...
# Analisando o processo 0000301-71.2015.8.26.0599...
# Analisando o processo 0018666-16.2007.8.26.0451...
# Analisando o processo 0000731-79.2015.8.26.0451...
# Analisando o processo 0018763-69.2014.8.26.0451...
# Analisando o processo 0019219-19.2014.8.26.0451...
# Analisando o processo 0000032-32.2015.8.26.0599...
# Analisando o processo 0025364-04.2008.8.26.0451...
# Analisando o processo 3003848-95.2013.8.26.0451...
# Analisando o processo 0008342-83.2015.8.26.0451...
# Analisando o processo 0000219-40.2015.8.26.0599...
# Analisando o processo 0000220-25.2015.8.26.0599...
# Analisando o processo 0015280-31.2014.8.26.0451...
# Analisando o processo 0009059-03.2012.8.26.0451...
# Analisando o processo 0005786-11.2015.8.26.0451...
# Analisando o processo 0013837-45.2014.8.26.0451...
# Analisando o processo 3012397-94.2013.8.26.0451...
# Analisando o processo 3000081-49.2013.8.26.0451...
# Analisando o processo 0000210-37.2015.8.26.0451...
# Analisando o processo 0016984-79.2014.8.26.0451...
# Analisando o processo 0031178-94.2008.8.26.0451...
# Analisando o processo 3000385-48.2013.8.26.0451...
# Analisando o processo 3007365-11.2013.8.26.0451...
# Analisando o processo 0003319-25.2016.8.26.0451...
# Analisando o processo 0002876-79.2013.8.26.0451...
# Analisando o processo 0034664-48.2012.8.26.0451...
# Analisando o processo 0009113-95.2014.8.26.0451...
# Analisando o processo 0000212-07.2015.8.26.0451...
# Analisando o processo 0003823-07.2011.8.26.0451...
# Analisando o processo 0026734-52.2007.8.26.0451...
# Analisando o processo 3010473-48.2013.8.26.0451...
# Analisando o processo 0028492-90.2012.8.26.0451...
# Analisando o processo 0013831-38.2014.8.26.0451...
# Analisando o processo 0015139-75.2015.8.26.0451...
# Analisando o processo 0018332-35.2014.8.26.0451...
# Analisando o processo 0015619-97.2008.8.26.0451...
# Analisando o processo 0007311-28.2015.8.26.0451...
# Analisando o processo 0016985-64.2014.8.26.0451...
# Analisando o processo 0020115-33.2012.8.26.0451...
# Analisando o processo 0003911-74.2013.8.26.0451...
# Analisando o processo 0023100-72.2012.8.26.0451...
# Analisando o processo 0014770-18.2014.8.26.0451...
# Analisando o processo 0015543-34.2012.8.26.0451...
# Analisando o processo 0002669-46.2014.8.26.0451...
# Analisando o processo 0031685-65.2002.8.26.0451...
# Analisando o processo 0012067-17.2014.8.26.0451...
# Analisando o processo 0000035-84.2015.8.26.0599...
# Analisando o processo 0013931-90.2014.8.26.0451...
# Analisando o processo 0000948-30.2012.8.26.0451...
# Analisando o processo 0005276-32.2014.8.26.0451...
# Analisando o processo 0032583-29.2012.8.26.0451...
# Analisando o processo 0053072-10.2000.8.26.0451...
# Analisando o processo 3007428-36.2013.8.26.0451...
# Analisando o processo 0017905-09.2012.8.26.0451...
# Analisando o processo 0033904-02.2012.8.26.0451...
# Analisando o processo 0005273-77.2014.8.26.0451...
# Analisando o processo 3003091-04.2013.8.26.0451...
# Analisando o processo 0018886-38.2012.8.26.0451...
# Analisando o processo 0010170-51.2014.8.26.0451...
# Analisando o processo 0020802-10.2012.8.26.0451...
# Analisando o processo 0001266-42.2014.8.26.0451...
# Analisando o processo 0003833-80.2013.8.26.0451...
# Analisando o processo 0012200-59.2014.8.26.0451...
# Analisando o processo 0023141-39.2012.8.26.0451...
# Analisando o processo 0010158-37.2014.8.26.0451...
# Analisando o processo 0029626-94.2008.8.26.0451...
# Analisando o processo 3011951-91.2013.8.26.0451...
# Analisando o processo 0002640-40.2007.8.26.0451...
# Analisando o processo 0021179-10.2014.8.26.0451...
# Analisando o processo 3000682-55.2013.8.26.0451...
# Analisando o processo 0016078-94.2011.8.26.0451...
# Analisando o processo 0001544-77.2013.8.26.0451...
# Analisando o processo 0009442-10.2014.8.26.0451...
# Analisando o processo 0008494-34.2015.8.26.0451...
# Analisando o processo 0002428-04.2016.8.26.0451...
# Analisando o processo 0005710-21.2014.8.26.0451...
# Analisando o processo 3007281-10.2013.8.26.0451...
# Analisando o processo 3007965-32.2013.8.26.0451...
# Analisando o processo 3001587-60.2013.8.26.0451...
# Analisando o processo 0023034-68.2007.8.26.0451...
# Analisando o processo 0001545-62.2013.8.26.0451...
# Analisando o processo 0009922-85.2014.8.26.0451...
# Analisando o processo 0005138-02.2013.8.26.0451...
# Analisando o processo 3014375-09.2013.8.26.0451...
# Analisando o processo 0035538-33.2012.8.26.0451...
# Analisando o processo 3000045-07.2013.8.26.0451...
# Analisando o processo 0023085-06.2012.8.26.0451...
# Analisando o processo 3013091-63.2013.8.26.0451...
# Analisando o processo 0000055-68.2014.8.26.0451...
# Analisando o processo 3008468-53.2013.8.26.0451...
# Analisando o processo 0005396-75.2014.8.26.0451...
# Analisando o processo 0019473-60.2012.8.26.0451...
# Analisando o processo 0001373-52.2015.8.26.0451...
# Analisando o processo 3000279-86.2013.8.26.0451...
# Analisando o processo 0004828-93.2013.8.26.0451...
# Analisando o processo 3015916-77.2013.8.26.0451...
# Analisando o processo 0003771-40.2013.8.26.0451...
# Analisando o processo 0021219-60.2012.8.26.0451...
# Analisando o processo 0000666-84.2015.8.26.0451...
# Analisando o processo 3010528-96.2013.8.26.0451...
# Analisando o processo 0004507-87.2015.8.26.0451...
# Analisando o processo 0007178-20.2014.8.26.0451...
# Analisando o processo 0033248-45.2012.8.26.0451...
# Analisando o processo 0006704-83.2013.8.26.0451...
# Analisando o processo 0016759-35.2009.8.26.0451...
# Analisando o processo 0020824-73.2009.8.26.0451...
# Analisando o processo 0003841-57.2013.8.26.0451...
# Analisando o processo 0010561-69.2015.8.26.0451...
# Analisando o processo 0031261-47.2007.8.26.0451...
# Analisando o processo 0009384-07.2014.8.26.0451...
# Analisando o processo 0010403-82.2013.8.26.0451...
# Analisando o processo 0010389-35.2012.8.26.0451...
# Analisando o processo 0014530-97.2012.8.26.0451...
# Analisando o processo 0015008-37.2014.8.26.0451...
# Analisando o processo 3006473-05.2013.8.26.0451...
# Analisando o processo 0008669-62.2014.8.26.0451...
# Analisando o processo 0005896-78.2013.8.26.0451...
# Analisando o processo 0020486-26.2014.8.26.0451...
# Analisando o processo 3014158-63.2013.8.26.0451...
# Analisando o processo 3016309-02.2013.8.26.0451...
# Analisando o processo 3004839-71.2013.8.26.0451...
# Analisando o processo 3008244-18.2013.8.26.0451...
# Analisando o processo 0008264-60.2013.8.26.0451...
# Analisando o processo 0006158-91.2014.8.26.0451...
# Analisando o processo 3009373-58.2013.8.26.0451...
# Analisando o processo 3001173-62.2013.8.26.0451...
# Analisando o processo 3002524-70.2013.8.26.0451...
# Analisando o processo 0003767-37.2012.8.26.0451...
# Analisando o processo 0008805-59.2014.8.26.0451...
# Analisando o processo 0009056-48.2012.8.26.0451...
# Analisando o processo 0028229-58.2012.8.26.0451...
# Analisando o processo 3012273-14.2013.8.26.0451...
# Analisando o processo 3004416-14.2013.8.26.0451...
# Analisando o processo 0000898-67.2013.8.26.0451...
# Analisando o processo 0008378-33.2012.8.26.0451...
# Analisando o processo 0017857-84.2011.8.26.0451...
# Analisando o processo 0000034-92.2014.8.26.0451...
# Analisando o processo 3005587-06.2013.8.26.0451...
# Analisando o processo 0007495-86.2012.8.26.0451...
# Analisando o processo 0010288-61.2013.8.26.0451...
# Analisando o processo 0031874-04.2006.8.26.0451...
# Analisando o processo 3007266-41.2013.8.26.0451...
# Analisando o processo 3006997-02.2013.8.26.0451...
# Analisando o processo 0010105-27.2012.8.26.0451...
# Analisando o processo 0009058-18.2012.8.26.0451...
# Analisando o processo 0008459-45.2013.8.26.0451...
# Analisando o processo 0004675-31.2011.8.26.0451...
# Analisando o processo 0014294-82.2011.8.26.0451...
# Analisando o processo 0010961-88.2012.8.26.0451...
# Analisando o processo 0029260-26.2006.8.26.0451...
# Analisando o processo 0054503-16.1999.8.26.0451...
# Analisando o processo 0002999-77.2013.8.26.0451...
# Analisando o processo 0036371-51.2012.8.26.0451...
# Analisando o processo 0052957-23.1999.8.26.0451...
# Analisando o processo 0004831-48.2013.8.26.0451...
# Analisando o processo 3001255-93.2013.8.26.0451...
# Analisando o processo 0000076-44.2014.8.26.0451...
# Analisando o processo 0003999-15.2013.8.26.0451...
# Analisando o processo 0018667-25.2012.8.26.0451...
# Analisando o processo 0015936-56.2012.8.26.0451...
# Analisando o processo 0007352-63.2013.8.26.0451...
# Analisando o processo 3008417-42.2013.8.26.0451...
# Analisando o processo 3006548-44.2013.8.26.0451...
# Analisando o processo 0027057-86.2009.8.26.0451...
# Analisando o processo 0019665-22.2014.8.26.0451...
# Analisando o processo 0005009-31.2012.8.26.0451...
# Analisando o processo 3009958-13.2013.8.26.0451...
# Analisando o processo 3009082-58.2013.8.26.0451...
# Analisando o processo 0009854-38.2014.8.26.0451...
# Analisando o processo 3004415-29.2013.8.26.0451...
# Analisando o processo 0008827-54.2013.8.26.0451...
# Analisando o processo 0035018-73.2012.8.26.0451...
# Analisando o processo 0010896-30.2011.8.26.0451...
# Analisando o processo 0015929-98.2011.8.26.0451...
# Analisando o processo 0033440-51.2007.8.26.0451...
# Analisando o processo 0015206-79.2011.8.26.0451...
# Analisando o processo 0014843-29.2010.8.26.0451...
# Analisando o processo 0026322-53.2009.8.26.0451...
# Analisando o processo 3007363-41.2013.8.26.0451...
# Analisando o processo 0021333-43.2005.8.26.0451...
# Analisando o processo 3005188-74.2013.8.26.0451...
# Analisando o processo 0035643-10.2012.8.26.0451...
# Analisando o processo 0025113-44.2012.8.26.0451...
# Analisando o processo 0010409-26.2012.8.26.0451...
# Analisando o processo 0000446-28.2011.8.26.0451...
# Analisando o processo 3002903-11.2013.8.26.0451...
# Analisando o processo 3007425-81.2013.8.26.0451...
# Analisando o processo 0028418-36.2012.8.26.0451...
# Analisando o processo 0012602-14.2012.8.26.0451...
# Analisando o processo 0028308-71.2011.8.26.0451...
# Analisando o processo 0010691-30.2013.8.26.0451...
# Analisando o processo 0005076-98.2009.8.26.0451...
# Analisando o processo 0007904-04.2008.8.26.0451...
# Analisando o processo 0008828-39.2013.8.26.0451...
# Analisando o processo 0010291-16.2013.8.26.0451...
# Analisando o processo 0021576-84.2005.8.26.0451...
# Analisando o processo 0021909-89.2012.8.26.0451...
# Analisando o processo 0034640-20.2012.8.26.0451...
# Analisando o processo 0013784-69.2011.8.26.0451...
# Analisando o processo 0035755-13.2011.8.26.0451...
# Analisando o processo 0035509-56.2007.8.26.0451...
# Analisando o processo 0014237-30.2012.8.26.0451...
# Analisando o processo 0006860-71.2013.8.26.0451...
# Analisando o processo 0021687-92.2010.8.26.0451...
# Analisando o processo 0021506-57.2011.8.26.0451...
# Analisando o processo 3002073-45.2013.8.26.0451...
# Analisando o processo 0003840-72.2013.8.26.0451...
# Analisando o processo 0035655-24.2012.8.26.0451...
# Analisando o processo 1008827-66.2015.8.26.0451...
# Analisando o processo 3007812-96.2013.8.26.0451...
# Analisando o processo 0029081-19.2011.8.26.0451...
# Analisando o processo 0012425-55.2009.8.26.0451...
# Analisando o processo 0020804-77.2012.8.26.0451...
# Analisando o processo 0028217-44.2012.8.26.0451...
# Analisando o processo 0019406-32.2011.8.26.0451...
# Analisando o processo 0000891-75.2013.8.26.0451...
# Analisando o processo 0028657-11.2010.8.26.0451...
# Analisando o processo 0015321-03.2011.8.26.0451...
# Analisando o processo 0017828-05.2009.8.26.0451...
# Analisando o processo 0007340-15.2014.8.26.0451...
# Analisando o processo 0024385-71.2010.8.26.0451...
# Analisando o processo 0008455-08.2013.8.26.0451...
# Analisando o processo 3004254-19.2013.8.26.0451...
# Analisando o processo 0035029-05.2012.8.26.0451...
# Analisando o processo 0008380-03.2012.8.26.0451...
# Analisando o processo 0035745-37.2009.8.26.0451...
# Analisando o processo 0028379-73.2011.8.26.0451...
# Analisando o processo 0022249-04.2010.8.26.0451...
# Analisando o processo 0027129-73.2009.8.26.0451...
# Analisando o processo 0021498-22.2007.8.26.0451...
# Analisando o processo 0025958-76.2012.8.26.0451...
# Analisando o processo 0003965-45.2010.8.26.0451...
# Analisando o processo 3001614-43.2013.8.26.0451...
# Analisando o processo 0027840-44.2010.8.26.0451...
# Analisando o processo 0020119-70.2012.8.26.0451...
# Analisando o processo 0026702-08.2011.8.26.0451...
# Analisando o processo 0033041-56.2006.8.26.0451...
# Analisando o processo 0000447-13.2011.8.26.0451...
# Analisando o processo 0001698-03.2010.8.26.0451...
# Analisando o processo 3016033-68.2013.8.26.0451...
# Analisando o processo 0034088-89.2011.8.26.0451...
# Analisando o processo 0014309-51.2011.8.26.0451...
# Analisando o processo 0005330-37.2010.8.26.0451...
# Analisando o processo 0009382-42.2011.8.26.0451...
# Analisando o processo 0015207-64.2011.8.26.0451...
# Analisando o processo 0021743-96.2008.8.26.0451...
# Analisando o processo 0027544-85.2011.8.26.0451...
# Analisando o processo 3000401-02.2013.8.26.0451...
# Analisando o processo 0026154-17.2010.8.26.0451...
# Analisando o processo 0015322-85.2011.8.26.0451...
# Analisando o processo 0028186-63.2008.8.26.0451...
# Analisando o processo 0021389-66.2011.8.26.0451...
# Analisando o processo 0002489-74.2007.8.26.0451...
# Analisando o processo 0025204-08.2010.8.26.0451...
# Analisando o processo 0027133-13.2009.8.26.0451...
# Analisando o processo 3007952-33.2013.8.26.0451...
# Analisando o processo 0034737-88.2010.8.26.0451...
# Analisando o processo 0012159-63.2012.8.26.0451...
# Analisando o processo 0017871-73.2008.8.26.0451...
# Analisando o processo 0004938-63.2011.8.26.0451...
# Analisando o processo 0001009-22.2011.8.26.0451...
# Analisando o processo 0013567-26.2011.8.26.0451...
# Analisando o processo 0004444-38.2010.8.26.0451...
# Analisando o processo 0025042-13.2010.8.26.0451...
# Analisando o processo 0010985-87.2010.8.26.0451...
# Analisando o processo 0015369-35.2006.8.26.0451...
# Analisando o processo 0034560-56.2012.8.26.0451...

# %%
# Cria um DataFrame a partir da lista de respostas
# A lista_de_respostas contém tuplas (numero_do_processo, dict_analise)
# Vamos expandir o dicionário em colunas do DataFrame

data_para_df = []
for numero_processo, analise_dict in lista_de_respostas:
  row_data = {'numero_do_processo': numero_processo}
  row_data.update(analise_dict) # Adiciona as chaves do dicionário como colunas
  data_para_df.append(row_data)

# %%
df_respostas = pd.DataFrame(data_para_df)
display(df_respostas.head(5))

df_respostas.to_csv(CSV_SENTENCAS_ANALISADAS, index=False, encoding='utf-8-sig')
print(f"Arquivo CSV salvo em: {CSV_SENTENCAS_ANALISADAS}")
# Out:
#           numero_do_processo      data_fato  \
# 0  1502313-93.2022.8.26.0451     13/10/2021
# 1  0009883-88.2014.8.26.0451  Não se aplica
# 2  1502947-89.2022.8.26.0451  Não se aplica
# 3  1502796-60.2021.8.26.0451  Não se aplica
# 4  0014888-04.2008.8.26.0451  Não se aplica
#
#                                        endereco_fato  \
# 0  Avenida Antônio Fazanaro, cruzamento com Rua E...
# 1                                      Não se aplica
# 2                                      Não se aplica
# 3                                      Não se aplica
# 4                                      Não se aplica
#
#                                      conduta_culposa
# 0  O condutor não observou o dever de cuidado ao ...
# 1                                      Não se aplica
# 2                                      Não se aplica
# 3                                      Não se aplica
# 4                                      Não se aplica
# Arquivo CSV salvo em: /content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas_analisadas.csv

# %%
df_geral = pd.merge(df_1, df_respostas, on='numero_do_processo')
df_geral.head(5)
# Out:
#           numero_do_processo                               classe  \
# 0  1502313-93.2022.8.26.0451  Ação Penal - Procedimento Ordinário
# 1  0009883-88.2014.8.26.0451    Ação Penal - Procedimento Sumário
# 2  1502947-89.2022.8.26.0451    Ação Penal - Procedimento Sumário
# 3  1502796-60.2021.8.26.0451    Ação Penal - Procedimento Sumário
# 4  0014888-04.2008.8.26.0451    Ação Penal - Procedimento Sumário
#
#               assunto                             magistrado     comarca  \
# 0  Crimes de Trânsito                Rodrigo Pares Andreucci  Piracicaba
# 1  Crimes de Trânsito  Flavia de Cassia Gonzales de Oliveira  Piracicaba
# 2  Crimes de Trânsito                           Gisela Ruffo  Piracicaba
# 3  Crimes de Trânsito          GABRIELA DE ALMEIDA VERGUEIRO  Piracicaba
# 4  Crimes de Trânsito                Rodrigo Pares Andreucci  Piracicaba
#
#                  foro              vara data_de_disponibilização  \
# 0  Foro de Piracicaba  3ª Vara Criminal               22/10/2025
# 1  Foro de Piracicaba  2ª Vara Criminal               09/10/2025
# 2  Foro de Piracicaba  4ª Vara Criminal               06/10/2025
# 3  Foro de Piracicaba  4ª Vara Criminal               21/11/2025
# 4  Foro de Piracicaba  3ª Vara Criminal               19/11/2025
#
#                                             sentenca      data_fato  \
# 0  SENTENÇA\n\nProcesso Digital nº:\t1502313-93.2...     13/10/2021
# 1  SENTENÇA\n\nProcesso nº:\t0009883-88.2014.8.26...  Não se aplica
# 2  SENTENÇA\n\nProcesso nº:\t1502947-89.2022.8.26...  Não se aplica
# 3  SENTENÇA\n\nProcesso nº:\t1502796-60.2021.8.26...  Não se aplica
# 4  SENTENÇA\n\nProcesso nº:\t0014888-04.2008.8.26...  Não se aplica
#
#                                        endereco_fato  \
# 0  Avenida Antônio Fazanaro, cruzamento com Rua E...
# 1                                      Não se aplica
# 2                                      Não se aplica
# 3                                      Não se aplica
# 4                                      Não se aplica
#
#                                      conduta_culposa
# 0  O condutor não observou o dever de cuidado ao ...
# 1                                      Não se aplica
# 2                                      Não se aplica
# 3                                      Não se aplica
# 4                                      Não se aplica

# %%
df_geral_com_endereco = df_geral[df_geral['endereco_fato'] != 'Não se aplica']
print(len(df_geral_com_endereco))

df_geral_com_endereco.to_csv(CSV_SENTENCAS_COM_ENDERECOS, index=False, encoding='utf-8-sig')
print(f"Arquivo CSV salvo em: {CSV_SENTENCAS_COM_ENDERECOS}")
# Out:
# 115
# Arquivo CSV salvo em: /content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas_com_enderecos.csv

# %% [markdown]
# # Georreferenciamento do dataframe

# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from googlemaps) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2026.1.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40714 sha256=8cdfa64ffcf407c33222923a4f9bbc302f7290c57d7814f921dd34fa38257cc5
#   Stored in directory: /root/.cache/pip/wheels/4c/6a/a7/bbc6f5c200032025ee655deb5e163ce8594fa05e67d973aad6
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
# Georreferenciar com o Google
import googlemaps
from google.colab import userdata

def buscar_coords(endereco):
    if not endereco:
        return None, None

    gmaps = googlemaps.Client(key=userdata.get('geo_google'))
    geocode_result = gmaps.geocode(endereco)

    if geocode_result:
        lat = geocode_result[0]['geometry']['location']['lat']
        lng = geocode_result[0]['geometry']['location']['lng']
        return lat, lng
    else:
        print("Endereço não encontrado.")
        return None, None

# %%
df_geral_com_endereco[['latitude', 'longitude']] = df_geral_com_endereco['endereco_fato'].apply(
    lambda x: pd.Series(buscar_coords(x))
)
# Out:
# /tmp/ipython-input-419336096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geral_com_endereco[['latitude', 'longitude']] = df_geral_com_endereco['endereco_fato'].apply(
# /tmp/ipython-input-419336096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geral_com_endereco[['latitude', 'longitude']] = df_geral_com_endereco['endereco_fato'].apply(

# %%
df_geral_com_endereco.head(5)
# Out:
#            numero_do_processo                               classe  \
# 0   1502313-93.2022.8.26.0451  Ação Penal - Procedimento Ordinário
# 6   1501240-52.2023.8.26.0451  Ação Penal - Procedimento Ordinário
# 11  1510468-51.2023.8.26.0451  Ação Penal - Procedimento Ordinário
# 12  1502522-67.2019.8.26.0451  Ação Penal - Procedimento Ordinário
# 22  1509412-80.2023.8.26.0451  Ação Penal - Procedimento Ordinário
#
#                assunto                       magistrado     comarca  \
# 0   Crimes de Trânsito          Rodrigo Pares Andreucci  Piracicaba
# 6   Crimes de Trânsito  Ana Claudia Madeira de Oliveira  Piracicaba
# 11  Crimes de Trânsito          Rodrigo Pares Andreucci  Piracicaba
# 12  Crimes de Trânsito                     Gisela Ruffo  Piracicaba
# 22  Crimes de Trânsito  Ana Claudia Madeira de Oliveira  Piracicaba
#
#                   foro              vara data_de_disponibilização  \
# 0   Foro de Piracicaba  3ª Vara Criminal               22/10/2025
# 6   Foro de Piracicaba  1ª Vara Criminal               31/10/2025
# 11  Foro de Piracicaba  3ª Vara Criminal               15/07/2025
# 12  Foro de Piracicaba  4ª Vara Criminal               10/07/2025
# 22  Foro de Piracicaba  1ª Vara Criminal               29/04/2025
#
#                                              sentenca   data_fato  \
# 0   SENTENÇA\n\nProcesso Digital nº:\t1502313-93.2...  13/10/2021
# 6   SENTENÇA\n\nProcesso Digital nº:\t1501240-52.2...  09/12/2020
# 11  SENTENÇA\n\nProcesso Digital nº:\t1510468-51.2...  21/10/2023
# 12  SENTENÇA\n\nProcesso Digital nº:\t1502522-67.2...  23/12/2018
# 22  SENTENÇA\n\nProcesso Digital nº:\t1509412-80.2...  22/06/2023
#
#                                         endereco_fato  \
# 0   Avenida Antônio Fazanaro, cruzamento com Rua E...
# 6   Rodovia SP-304, Bairro Santa Terezinha, Piraci...
# 11  Rua Santa Olímpia, estrada vicinal, bairro San...
# 12  Rodovia SP-147, Km 153, bairro Castelinho, Pir...
# 22  Rua Clara Nunes, 448, bairro Glebas Aliança, P...
#
#                                       conduta_culposa   latitude  longitude
# 0   O condutor não observou o dever de cuidado ao ... -22.740622 -47.644175
# 6                                       Não se aplica -22.686229 -47.672379
# 11  O acusado (A.A.F.) conduzia veículo em velocid... -22.614901 -47.744669
# 12  Colisão frontal em curva acentuada, em trecho ... -22.713587 -47.653236
# 22  O acidente decorreu da imprudência e negligênc... -22.757028 -47.609179

# %%
# Salvar o DataFrame georreferenciado em um novo arquivo CSV
df_geral_com_endereco.to_csv(CSV_SENTENCAS_GEORREFERENCIADAS, index=False, encoding='utf-8-sig')
print(f"DataFrame de respostas salvo em: {CSV_SENTENCAS_GEORREFERENCIADAS}")
# Out:
# DataFrame de respostas salvo em: /content/drive/MyDrive/Promotoria/Acidentes de trânsito/sentencas_georreferenciadas.csv

# %%
import folium
from folium.plugins import MarkerCluster

# 2. Criar o mapa base (centralizado em uma coordenada média ou inicial)
mapa = folium.Map(location=[-22.7801, -47.66], zoom_start=10)

# 3. Criar o Cluster
marker_cluster = MarkerCluster().add_to(mapa)

# 4. Adicionar os marcadores ao cluster
for idx, row in df_geral_com_endereco.iterrows():
    # Só adiciona se houver coordenadas válidas
    if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
        pop_up_text = f"<b>Processo:</b> {row['numero_do_processo']}<br><b>Conduta:</b> {row['conduta_culposa']}"

        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=folium.Popup(pop_up_text, max_width=300),
            tooltip=f"Processo {row['numero_do_processo']}"
        ).add_to(marker_cluster)

# Salvar ou exibir
mapa.save("mapa_processos_cluster.html")
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2650dc9370469ae1dd91453715ff652b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2650dc9370469ae1dd91453715ff652b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2650dc9370469ae1dd91453715ff652b = L.map(
#                 &quot;map_2650dc9370469ae1dd91453715ff652b&quot;,
#                 {
#                     center: [-22.7801, -47.66],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95f858c19751bc0dc8a9c131b5110392 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95f858c19751bc0dc8a9c131b5110392.addTo(map_2650dc9370469ae1dd91453715ff652b);
#
#
#             var marker_cluster_32c4d6d4195a215b77277b65dd675f58 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_104dc4ad6590ba2e5aeaf2fbf85b5ecf = L.marker(
#                 [-22.7406217, -47.644175],
#                 {
# }
#             ).addTo(marker_cluster_32c4d6d4195a215b77277b65dd675f58);
#
#
#         var popup_c23a6cd7feeeb4c49d2822f89b596a2b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_dd5a6e2f549cab2084a2f76b8c8ac534 = $(`&lt;div id=&quot;html_dd5a6e2f549cab2084a2f76b8c8ac534&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Processo:&lt;/b&gt; 1502313-93.2022.8.26.0451&lt;br&gt;&lt;b&gt;Conduta:&lt;/b&gt; O condutor não observou o dever de cuidado ao não efetuar parada completa no sinal de PARE, apenas reduziu a velocidade e prosseguiu sem verificar a presença de pedestres. Olhou apenas para a esquerda em busca de veículos, desconsiderando pedestres vindo da calçada/por trás de um poste. Mantinha cerca de 50 km/h e não freou a tempo, evidenciando imprudência e negligência na condução.&lt;/div&gt;`)[0];
#                 popup_c23a6cd7feeeb4c49d2822f89b596a2b.setContent(html_dd5a6e2f549cab2084a2f76b8c8ac534);
#
#
#
#         marker_104dc4ad6590ba2e5aeaf2fbf85b5ecf.bindPopup(popup_c23a6cd7feeeb4c49d2822f89b596a2b)
#         ;
#
#
#
#
#             marker_104dc4ad6590ba2e5aeaf2fbf85b5ecf.bindTooltip(
#                 `&lt;div&gt;
#                      Processo 1502313-93.2022.8.26.0451
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_771afda6a663408d52ec775ab6f590c8 = L.marker(
#                 [-22.6862292, -47.6723795],
#                 {
# }
#             ).addTo(marker_cluster_32c4d6d4195a215b77277b65dd675f58);
#
#
#         var popup_0af45f17131cba2c3004e7c3c8f86b0e = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_546d1ded595995de33c5805ae97c8ccf = $(`&lt;div id=&quot;html_546d1ded595995de33c5805ae97c8ccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Processo:&lt;/b&gt; 1501240-52.2023.8.26.0451&lt;br&gt;&lt;b&gt;Conduta:&lt;/b&gt; Não se aplica&lt;/div&gt;`)[0];
#                 popup_0af45f17131cba2c3004e7c3c8f86b0e.setContent(html_546d1ded595995de33c5805ae97c8ccf);
#
#
#
#         marker_771afda6a663408d52ec775ab6f590c8.bindPopup(popup_0af45f17131cba2c3004e7c3c8f86b0e)
#         ;
#
#
#
#
#             marker_771afda6a663408d52ec775ab6f590c8.bindTooltip(
#                 `&lt;div&gt;
#                      Processo 1501240-52.2023.8.26.0451
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_80d1174651e763692543472c4c4ae1ae = L.marker(
#                 [-22.6149012, -47.7446687],
#                 {
# }
#             ).addTo(marker_cluster_32c4d6d4195a215b77277b65dd675f58);
#
#
#         var popup_a89b2588d560f1d2b9c64e31b7da4d8f = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_95de0b532d7e2c61289f4098fed7fd29 = $(`&lt;div id=&quot;html_95de0b532d7e2c61289f4098fed7fd29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Processo:&lt;/b&gt; 1510468-51.2023.8.26.0451&lt;br&gt;&lt;b&gt;Conduta:&lt;/b&gt; O acusado (A.A.F.) condu
